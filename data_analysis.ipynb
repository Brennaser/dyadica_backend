# %%
import pandas as pd
import json

# %%
max_pair_scores = None
pairs_made = None
pairs_declined = None
opt_outs = None

with open('dyadica_data.json', 'r') as f:
    data = json.load(f)
    max_pair_scores = pd.read_json(data['max_pair_scores'])
    pairs_made = pd.Series(data["pairs_made"])
    pairs_declined = pd.Series(data["pairs_declined"])
    opt_outs = pd.Series(data['opt_outs'])
# Out:
# <ipython-input-9-8a8dd3b1258e>:9: FutureWarning: Passing literal json to 'read_json' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   max_pair_scores = pd.read_json(data['max_pair_scores'])

# %%
max_pair_scores
# Out:
#        1      2      3      4      5      6      7
# 1    NaN  0.000  0.750  0.000  1.000  0.875  0.000
# 2  0.000    NaN  0.750  0.000  1.000  0.875  0.000
# 3  0.750  0.750    NaN  0.875  0.750  0.875  1.000
# 4  0.000  0.000  0.875    NaN  0.875  1.000  0.000
# 5  1.000  1.000  0.750  0.875    NaN  0.000  0.750
# 6  0.875  0.875  0.875  1.000  0.000    NaN  0.875
# 7  0.000  0.000  1.000  0.000  0.750  0.875    NaN

# %%
pairs_made
# Out:
# 1    [[7, 3], [5, 1]]
# 2    [[5, 2], [3, 4]]
# 3            [[6, 4]]
# 4            [[7, 6]]
# 5    [[6, 1], [7, 5]]
# 6    [[6, 2], [5, 3]]
# 7    [[6, 3], [5, 1]]
# 8    [[2, 3], [6, 7]]
# 9    [[1, 3], [5, 2]]
# dtype: object

# %%
# Shim sham was round 5 based on P1's Post-survey response about using the decline feature

# %%
opt_outs
# Out:
# 6                           [[0, False], [2, True]]
# 3    [[2, False], [2, True], [3, False], [5, True]]
# 4                                      [[3, False]]
# dtype: object

# %%
pairs_declined.loc['7'].append([5, 1])

# %%
pairs_declined.loc['8'].pop(2)
# Out:
# [5, 1]

# %%
pairs_declined
# Out:
# 3            [[4, 6]]
# 5    [[5, 7], [1, 6]]
# 7    [[3, 6], [5, 1]]
# 8    [[3, 2], [6, 7]]
# 9    [[2, 5], [3, 1]]
# dtype: object

# %%
# Adjusted pairs_declined; [5,1] was assigned in round 7. Race conditions meant the decline was logged during round 8
